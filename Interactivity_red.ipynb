# %%
# Again we need to change the backend to display dynamic content
# best to only run this cell once, at the beginning!
# %matplotlib not

import numpy as np
import matplotlib.pyplot as plt

#interactive widgets package
import ipywidgets as ipyw
from IPython.display import HTML

plt.ioff();
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-0944a4c4f0fa> in <module>
#       1 # Again we need to change the backend to display dynamic content
#       2 # best to only run this cell once, at the beginning!
# ----> 3 get_ipython().run_line_magic('matplotlib', 'widget')
#       4
#       5 import numpy as np
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2324                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2325             with self.builtin_trap:
# -> 2326                 result = fn(*args, **kwargs)
#    2327             return result
#    2328
#
# ~\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# ...

# %%
fig2 = plt.figure(figsize=(5,4))
x = np.linspace(0, 2 * np.pi)

ax = fig2.add_subplot(1, 1, 1)
w=1.0
line, = ax.plot(x, np.sin(w*x))

ax.set_xlabel( r'$x$' , fontsize=14)
ax.set_ylabel( r'$\sin\,( %.2lf \, x)$' % w, fontsize=14)

plt.tight_layout()

def update(change):
    w=the_slider.value
    line.set_ydata(np.sin(w * x))
    ax.set_ylabel( r'$\sin\,( %.2lf \, x)$' % w)
    fig2.canvas.draw()

    
the_slider = ipyw.FloatSlider(description ='w', min=0.5, max=4, step=0.1, value=1.0)

the_slider.observe(update, 'value')
    
the_slider
# Out:
# FloatSlider(value=1.0, description='w', max=4.0, min=0.5)
